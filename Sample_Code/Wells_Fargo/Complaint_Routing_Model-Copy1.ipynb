# %% [markdown]
# # Complaint Routing Model

# %% [markdown]
# #### by Jeffrey Strickland, Ph.D.
# #### 12 August 2019

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Goal: route complaints to the proper researched team based on product groupings.
#
# The business unit receives complaintsin the form of free text and wants to route the complaints to the wants to route the complaints to one of seven different depaertments (product_group name in the daata parenthesis:.
# 	1. Bank account or service (bank_servie)
# 	2. Credit card (credit_card)
# 	3. Credit reporting (credict_reporting)
# 	4. Debt collection (debt_collection)
# 	5. Lines of loans (loan)
# 	6. Money Transfers (money_transfers)
# 	7. Mortgage (mortgange)
#
# We have obtained a data set wiith 286,362 records that contains complaint text (text), a message identifier (complaint_id) and a verified correct complaint department product_group).

# %% [markdown]
# ### Methodology
#
# - We created three differnet classification models for comparison:
#
#     - Naive Bayes
#     - Classification Tree
#     - Random Forest
#
# - For of natural language processing (NLP) we chose the bag-of-words method.

# %% [markdown]
# ## Load Required Packages

# %%
#Standard packages
import pandas as pd
import numpy as np
import matplotlib


# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Scikit Learn
from sklearn import preprocessing
from sklearn import tree
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold

#Natural Language Toolkit
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lemmatiser = WordNetLemmatizer()

#String
import string

from matplotlib import pyplot as plt
# Allow plots in Notebook
# %matplotlib inline

# %% [markdown]
# ## Optional Packages

# %%
#Plotly
import plotly
import plotly.graph_objects as go
import plotly.express as px
import chart_studio.plotly as py
import re
from sodapy import Socrata
from pprint import pprint

# Spacy for lemmatization
import spacy

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
import seaborn as sns
#nltk.download('punkt')
#nltk.download('wordnet')

# %% [markdown]
# ### Loading (reading) the Dataset using Pandas
# Our first step in the modeling process is to load the data. In this instance the data is contained in a CVS file that we will read into the Jupyter Notebook.

# %%
df = pd.read_csv("D:/Documents/Data/case_study_data_copy.csv")
corps = df[['complaint_id','product_group','text']]

# %% [markdown]
# ### Data Exploration
# The next several step we take are for exploring the complaint data, including listing the headings, viewing some records, and assessing the shape of the data frame.

# %%
list(corps)
# Out:
# ['complaint_id', 'product_group', 'text']

# %%
corps.shape, train.shape, test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2d3a1677a75b> in <module>()
# ----> 1 corps.shape, train.shape, test.shape
#
# NameError: name 'train' is not defined

# %% [markdown]
# ### Data Exploration

# %%
corps.head(5) # for showing a snapshot of the dataset
# Out:
#    complaint_id product_group  \
# 0       2815595  bank_service
# 1       2217937  bank_service
# 2       2657456  bank_service
# 3       1414106  bank_service
# 4       1999158  bank_service
#
#                                                 text
# 0  On check was debited from checking account and...
# 1   opened a Bank of the the West account The acc...
# 2   in nj opened a business account without autho...
# 3  A hold was placed on saving account because in...
# 4  Dear CFPBneed to send a major concerncomplaint...

# %% [markdown]
# ## Prepare a Frequency Distribution
#
# The next step consist of plotting the frequency of complaints for each product group and plotting the word counts

# %%
# Provides calculation of the shape of the data for each product group
bank_service_len = df[df['product_group'] == 'bank_service'].shape[0]
mortgage_len = df[df['product_group'] == 'mortgage'].shape[0]
credit_reporting_len = df[df['product_group'] == 'credit_reporting'].shape[0]
loan_len = df[df['product_group'] == 'loan'].shape[0]
credit_card_len = df[df['product_group'] == 'credit_card'].shape[0]
debt_collection_len = df[df['product_group'] == 'debt_collection'].shape[0]
money_transfers_len = df[df['product_group'] == 'money_transfers'].shape[0]

# %%
# Returns that complaint frequencies for each product group
credit_reporting_len, mortgage_len, bank_service_len, loan_len, credit_card_len, money_transfers_len
# Out:
# (81234, 40281, 20071, 31036, 29553, 4734)

# %% [markdown]
# ## Plotting the Data

# %%
# Sets up the data for construct the frequency distribution (bar chart)
plt.bar(10,bank_service_len,3, label="bank_service")
plt.bar(15,credit_card_len,3, label="credit_card")
plt.bar(20,credit_reporting_len,3, label="credit_reporting")
plt.bar(25,debt_collection_len,3, label="debt_collection")
plt.bar(30,loan_len,3, label="loan")
plt.bar(35,money_transfers_len,3, label="money_transfers")
plt.bar(40,mortgage_len,3, label="mortgage")
plt.legend()
plt.ylabel('Number of samples')
plt.title('Proportion of samples')
plt.show()

# %% [markdown]
# ## Store Product Group Data

# %% [markdown]
# The next step, and optional one, is to store the data for each product group into its own object for later use (potentially)

# %%
bks = df[df.product_group=="bank_service"]["text"].values
mtg = df[df.product_group=="mortgage"]["text"].values
crp = df[df.product_group=="credit_reporting"]["text"].values
ccd = df[df.product_group=="credit_card"]["text"].values
lon = df[df.product_group=="loan"]["text"].values
dct = df[df.product_group=="debt_collection"]["text"].values
mts = df[df.product_group=="money_transfers"]["text"].values

# %% [markdown]
# ## Text Processing Steps:
#
# 1. Removal of Punctuation → All the punctuation marks are removed from all the text-snippets (instances or documents) from the dataset (corpus).
# 1. Lemmatisation → Inflected forms of a word are known as lemma. For example, (studying, studied) are inflected forms or lemma of the word study which is the root word. So, the lemma of a word are grouped under the single root word. This is done to make the vocabulary of words in the corpus contain distinct words only.
# 1. Removal of Stopwords → Stop-words are usually articles (a, an, the), prepositions (in, on, under, …) and other frequently occurring words that do not provide any key or necessary information. They are removed from all the text-snippets present in the dataset (corpus).

# %%
# Defining a module for Text Processing
def text_process(tex):
    
# 1. Removal of Punctuation Marks 
    nopunct=[char for char in tex if char not in string.punctuation]
    nopunct=''.join(nopunct)

# 2. Lemmatisation 
    a=''
    i=0
    for i in range(len(nopunct.split())):
        b=lemmatiser.lemmatize(nopunct.split()[i], pos="v")
        a=a+b+' '

# 3. Removal of Stopwords
    return [word for word in a.split() if word.lower() not 
            in stopwords.words('english')]

# %%
def text_prep(tex):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in tex if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
X = corps['text']

# %%
y = corps['product_group']

# %% [markdown]
# ## Label Encoding of Classes:
#
# - As this is a classification problem, here classes are the 7 product groups as mentioned. In our dataset, the labels are non-numeric (bank_services, credit_card, credit_reporting, debt_collection, loan, money_transfers, and mortgage).
# - These are label encoded to make them numeric, starting from 0 depicting each label in the alphabetic order i.e., (0 → bank_services, 1 → credit_card, 2 → credit_reporting, 3 → debt_collection, 4 → loan, 5 → money_transfers, and 5 → mortgage).

# %%
# Importing necessary libraries
from sklearn.preprocessing import LabelEncoder
#y = corps['product_group']
#X = corps['text']
labelencoder = LabelEncoder()
yL = labelencoder.fit_transform(y)

# %%
print(labelencoder.fit_transform(y))
# Out:
# [0 0 0 ... 6 6 6]

# %% [markdown]
# ## Word Cloud Visualization:
#
# We developed the word clouds as follows:
#
# - Product groups have their own unique words and phrases, as well as some common ones
# - visualization of the mostly-used words to the least-used words for the product groups can be demonstrated
# - Seven text snippets, each belonging to the seven product groups, respectively, can render a Word Cloud

# %%
# Importing necessary libraries
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt

X = df['text']

wordcloud0 = WordCloud().generate(X[0]) # for bank_service
wordcloud1 = WordCloud().generate(X[1]) # for credit_card
wordcloud2 = WordCloud().generate(X[2]) # for credit_reporting 
wordcloud3 = WordCloud().generate(X[3]) # for debt_collection 
wordcloud4 = WordCloud().generate(X[4]) # for loan
wordcloud5 = WordCloud().generate(X[5]) # for money_transfers
wordcloud6 = WordCloud().generate(X[6]) # for mortgage

# %%
#print(X[0])
print(df['product_group'][0])
plt.imshow(wordcloud0, interpolation='bilinear')
plt.show()
# Out:
# bank_service

# %%
#print(X[22100])
print(df['product_group'][22100])
plt.imshow(wordcloud1, interpolation='bilinear')
plt.show()
# Out:
# credit_card

# %%
#print(X[42000])
print(df['product_group'][42000])
plt.imshow(wordcloud2, interpolation='bilinear')
plt.show()
# Out:
# credit_card

# %%
#print(X[152100])
print(df['product_group'][152100])
plt.imshow(wordcloud3, interpolation='bilinear')
plt.show()
# Out:
# debt_collection

# %%
#print(X[199100])
print(df['product_group'][199100])
plt.imshow(wordcloud4, interpolation='bilinear')
plt.show()
# Out:
# loan

# %%
#print(X[227100])
print(df['product_group'][227100])
plt.imshow(wordcloud5, interpolation='bilinear')
plt.show()
# Out:
# money_transfers

# %%
#print(X[237100])
print(df['product_group'][237100])
plt.imshow(wordcloud6, interpolation='bilinear')
plt.show()
# Out:
# mortgage

# %% [markdown]
# ## Create Train and Test Sets

# %%
# Importing necessary libraries
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

#80-20 splitting the dataset (80%->Training and 20%->Validation)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %% [markdown]
# ## Feature Engineering using Bag-of-Words:
#
# - Machine Learning Algorithms work only on numeric data.
# - But here, data is present in the form of text only.
# - For that, by some means, textual data needs to be transformed into numeric form.
# - One such approach of doing this, is Feature Engineering.
# - In this approach, numeric features are extracted or engineered from textual data.
# - There are many Feature Engineering Techniques in existence.
# - In this problem, Bag-of-Words Technique of Feature Engineering has been used.

# %% [markdown]
# ### Bag-of-Words (BOW):
#
# - With Bag-of-Words a vocabulary of words present in the corpus is maintained.
# - These words serve as features for each instance or document (each complaint).
# - Against each word as feature, its frequency in the current document (complaint) is considered.
# - In this way word features are engineered or extracted from the textual data or corpus.

# %% [markdown]
# ### BOW Preparation

# %%
import nltk
# create the transform
vectorizer = CountVectorizer()
# tokenize and build vocab
#word_vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 2), min_df=1)
#text_train = word_vectorizer.fit(X_train)
#text_test = word_vectorizer.fit(X_test)

# %%
# Defining the bag-of-words transformer on the text-processed corpus 
# i.e., text_process() declared in II is executed...
# nltk.download('stopwords')
import nltk
# create the transform
vectorizer = CountVectorizer()
bow_transformer_train=CountVectorizer().fit(X_train)
bow_transformer_test=CountVectorizer().fit(X_test)

# %%
from sklearn.feature_extraction.text import HashingVectorizer
# list of text documents
#text = X
# create the transform
#vectorizer = HashingVectorizer(n_features=20)
# encode document
#vector = vectorizer.transform(text)
# summarize encoded vector
#print(vector.shape)
#print(vector.toarray())

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
bow_transformer=CountVectorizer(analyzer=text_prep).fit(X_train)

# %%
# transforming into Bag-of-Words and hence textual data to numeric..
text_bow_train=bow_transformer.transform(X_train)#ONLY TRAINING DATA

# %%
# transforming into Bag-of-Words and hence textual data to numeric..
text_bow_test=bow_transformer.transform(X_test)#TEST DATA

# %%
print(text_bow_train)
# Out:
#   (0, 51840)	1
#   (0, 52120)	1
#   (0, 59641)	1
#   (0, 65939)	1
#   (0, 68315)	2
#   (0, 70586)	1
#   (0, 73127)	1
#   (0, 78900)	1
#   (0, 83366)	1
#   (0, 85115)	1
#   (0, 90335)	1
#   (0, 93394)	1
#   (0, 93510)	1
#   (0, 94403)	1
#   (0, 96701)	1
#   (0, 102012)	1
#   (0, 103789)	2
#   (0, 109404)	1
#   (0, 119580)	1
#   (0, 124540)	2
#   (0, 131716)	1
#   (1, 3108)	1
#   (1, 7197)	5
#   (1, 11054)	1
#   (1, 21045)	3
#   :	:
#   (187865, 86804)	2
#   (187865, 87836)	1
#   (187865, 92627)	2
#   (187865, 92691)	1
#   (187865, 97906)	1
#   (187865, 97932)	1
#   (187865, 99784)	1
#   (187865, 100147)	1
#   (187865, 102847)	3
#   (187865, 102857)	1
#   (187865, 109677)	1
#   (187865, 110808)	1
#   (187865, 111362)	1
#   (187865, 112207)	2
#   (187865, 112644)	1
#   (187865, 113195)	1
#   (187865, 115842)	1
#   (187865, 116223)	2
#   (187865, 117159)	1
#   (187865, 117548)	2
#   (187865, 118245)	1
#   (187865, 120968)	1
#   (187865, 128601)	2
#   (187865, 129305)	1
#   (187865, 130560)	1

# %%
print(text_bow_test)
# Out:
#   (0, 136)	1
#   (0, 6382)	1
#   (0, 7011)	1
#   (0, 14084)	2
#   (0, 14355)	2
#   (0, 18348)	2
#   (0, 21454)	1
#   (0, 21490)	1
#   (0, 22739)	1
#   (0, 37725)	3
#   (0, 40755)	1
#   (0, 42903)	1
#   (0, 51280)	1
#   (0, 51584)	1
#   (0, 52311)	7
#   (0, 52475)	11
#   (0, 54600)	2
#   (0, 55129)	1
#   (0, 55657)	1
#   (0, 56119)	3
#   (0, 56131)	1
#   (0, 57062)	2
#   (0, 57271)	1
#   (0, 57530)	1
#   (0, 57615)	1
#   :	:
#   (80513, 107877)	1
#   (80513, 109645)	1
#   (80513, 110131)	1
#   (80513, 111639)	1
#   (80513, 112629)	2
#   (80513, 114956)	1
#   (80513, 115747)	1
#   (80513, 116151)	1
#   (80513, 116223)	1
#   (80513, 117380)	1
#   (80513, 119412)	1
#   (80513, 119417)	2
#   (80513, 119562)	1
#   (80513, 119580)	1
#   (80513, 123573)	1
#   (80513, 125800)	2
#   (80513, 126035)	1
#   (80513, 128126)	1
#   (80513, 128297)	1
#   (80513, 128362)	1
#   (80513, 129305)	1
#   (80513, 130809)	1
#   (80513, 131377)	1
#   (80513, 131846)	1
#   (80513, 132158)	1

# %% [markdown]
# ## Training the Multinomial Naive Bayes Model:
#
# Multinomial Naive Bayes Algorithm (Classifier) has been used as the Classification Machine Learning Algorithm [1].

# %%
from sklearn.naive_bayes import MultinomialNB
#clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
X_train.size, text_bow_train.size, y_train.size
# Out:
# (187866, 11571246, 187866)

# %%
# Importing necessary libraries
from sklearn.naive_bayes import MultinomialNB

# instantiating the model with Multinomial Naive Bayes..
model = MultinomialNB()

# training the model...
model = model.fit(text_bow_train, y_train)

# %%
model.score(text_bow_train, y_train)
# Out:
# 0.8269032182513067

# %% [markdown]
# ### Model Performance Analysis:
#
# #### Training Accuracy

# %%
X_train.size, text_bow_train.size, y_train.size
# Out:
# (187866, 11571246, 187866)

# %%
X_test.size, text_bow_test.size, y_test.size
# Out:
# (80514, 4941354, 80514)

# %%
bayes_score = model.score(text_bow_test, y_test)
bayes_score
# Out:
# 0.8131132473855479

# %% [markdown]
# #### Validation Accuracy

# %%
bayes_val_score = model.score(text_bow_test, y_test)
bayes_val_score
# Out:
# 0.8131132473855479

# %% [markdown]
# The cross-validation score is very close to the model score, 80.99 versus 82.44. The naive Bayes model is a good fit of the data and will produce good predictions.

# %% [markdown]
# ### Precision, Recall and F1–Score

# %%
# Importing necessary libraries
from sklearn.metrics import classification_report
 
# getting the predictions of the Validation Set...
bayes_preds = model.predict(text_bow_test)

# getting the Precision, Recall, F1-Score
print(classification_report(y_test,bayes_preds))
# Out:
#                   precision    recall  f1-score   support
#
#     bank_service       0.76      0.82      0.79      5999
#      credit_card       0.73      0.77      0.75      8847
# credit_reporting       0.83      0.83      0.83     24445
#  debt_collection       0.83      0.77      0.80     18481
#             loan       0.74      0.78      0.76      9314
#  money_transfers       0.90      0.58      0.70      1422
#         mortgage       0.90      0.92      0.91     12006
#
#      avg / total       0.81      0.81      0.81     80514

# %% [markdown]
# ### Naive Bayes Predictions

# %%
bayes_preds[0:10]
# Out:
# array(['credit_reporting', 'credit_card', 'credit_reporting',
#        'credit_card', 'mortgage', 'credit_reporting', 'bank_service',
#        'debt_collection', 'credit_reporting', 'credit_reporting'],
#       dtype='<U16')

# %%
model.predict_proba(text_bow_test)
# Out:
# array([[1.96163636e-64, 3.68264399e-54, 1.00000000e+00, ...,
#         1.82289745e-69, 4.34615419e-98, 1.81945327e-69],
#        [9.86485846e-07, 9.98411675e-01, 1.58729751e-03, ...,
#         1.67364088e-11, 9.71595187e-13, 2.30865676e-13],
#        [1.39701122e-26, 9.66237698e-24, 1.00000000e+00, ...,
#         2.49981276e-22, 1.70599217e-32, 7.00265283e-31],
#        ...,
#        [2.09212552e-04, 9.99790787e-01, 2.68461844e-18, ...,
#         6.78341027e-14, 9.68134781e-16, 2.61362855e-15],
#        [1.41957712e-01, 5.85232805e-06, 1.46095100e-08, ...,
#         1.85685276e-12, 1.38358592e-19, 4.17527362e-16],
#        [5.33449772e-58, 2.38661955e-61, 2.27497748e-24, ...,
#         1.22994823e-47, 1.25568848e-84, 8.46819882e-14]])

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn import svm, datasets
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test,bayes_preds)
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure()
plot_confusion_matrix(cm, classes=[0,1,2,3,4,5,6])
# Out:
# Confusion matrix, without normalization
# [[ 4925   517   199    90    71    62   135]
#  [  561  6800   858   351   208    18    51]
#  [  152  1015 20331  1549   968     5   425]
#  [  113   530  2228 14273   995     6   336]
#  [  173   267   679   711  7268     2   214]
#  [  422   115    11    20    21   818    15]
#  [  116   110   321   162   244     1 11052]]

# %%
# Normalize the confusion matrix by row (i.e by the number of samples in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
plt.figure()
plot_confusion_matrix(cm_normalized, classes=[0,1,2,3,4,5,6],title='Normalized confusion matrix')
plt.show()
# Out:
# Normalized confusion matrix
# [[8.21e-01 8.62e-02 3.32e-02 1.50e-02 1.18e-02 1.03e-02 2.25e-02]
#  [6.34e-02 7.69e-01 9.70e-02 3.97e-02 2.35e-02 2.03e-03 5.76e-03]
#  [6.22e-03 4.15e-02 8.32e-01 6.34e-02 3.96e-02 2.05e-04 1.74e-02]
#  [6.11e-03 2.87e-02 1.21e-01 7.72e-01 5.38e-02 3.25e-04 1.82e-02]
#  [1.86e-02 2.87e-02 7.29e-02 7.63e-02 7.80e-01 2.15e-04 2.30e-02]
#  [2.97e-01 8.09e-02 7.74e-03 1.41e-02 1.48e-02 5.75e-01 1.05e-02]
#  [9.66e-03 9.16e-03 2.67e-02 1.35e-02 2.03e-02 8.33e-05 9.21e-01]]

# %% [markdown]
# # Training the Classification Tree Model

# %%
from sklearn import tree
clf_class = tree.DecisionTreeClassifier()
clf_class = clf_class.fit(text_bow_train, y_train)

# %%
clf_class
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# ### Classification Tree Scores

# %%
from sklearn import tree

# %%
tree_score = clf_class.score(text_bow_train, y_train)
tree_score
# Out:
# 0.9991802667859006

# %%
tree_val_score = clf.score(text_bow_test, y_test)
tree_val_score
# Out:
# 0.8131132473855479

# %% [markdown]
# The cross-validation score is much lower than the model score, 75.83 versus 99.91. The classificaton tree model is over-fitting the data and will produce numerous false positives.

# %% [markdown]
# ### Classification Tree Predictions

# %%
tree_preds = clf.predict(text_bow_test)
tree_preds[0:10]
# Out:
# array(['credit_reporting', 'credit_card', 'credit_reporting',
#        'credit_card', 'mortgage', 'credit_reporting', 'bank_service',
#        'debt_collection', 'credit_reporting', 'credit_reporting'],
#       dtype='<U16')

# %%
clf.predict_proba(text_bow_test)
# Out:
# array([[1.96e-64, 3.68e-54, 1.00e+00, ..., 1.82e-69, 4.35e-98, 1.82e-69],
#        [9.86e-07, 9.98e-01, 1.59e-03, ..., 1.67e-11, 9.72e-13, 2.31e-13],
#        [1.40e-26, 9.66e-24, 1.00e+00, ..., 2.50e-22, 1.71e-32, 7.00e-31],
#        ...,
#        [2.09e-04, 1.00e+00, 2.68e-18, ..., 6.78e-14, 9.68e-16, 2.61e-15],
#        [1.42e-01, 5.85e-06, 1.46e-08, ..., 1.86e-12, 1.38e-19, 4.18e-16],
#        [5.33e-58, 2.39e-61, 2.27e-24, ..., 1.23e-47, 1.26e-84, 8.47e-14]])

# %% [markdown]
# ### Tree Summary

# %% [markdown]
# According to the Performance Analysis, we can conclude that this model may be overfitting the data, given th significant difference wetween train and test scores.
# - Train: 99.91%
# - Test: 75.94%

# %% [markdown]
# # Training the Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.cross_validation import cross_val_score

# %%
rf = RandomForestClassifier(n_estimators=100) # initialize
rf.fit(text_bow_train, y_train) # fit the data to the algorithm
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ### Random Forest Model Scores

# %%
forest_score = rf.score(text_bow_train, y_train)
forest_score
# Out:
# 0.9991802667859006

# %%
forest_val_score = rf.score(text_bow_test, y_test)
forest_val_score
# Out:
# 0.8239188215714037

# %%
rf.get_params(rf.fit)
# Out:
# {'bootstrap': True,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ### Random Forest Predictions

# %%
forest_preds = rf.predict(text_bow_test)
forest_preds[0:10]
# Out:
# array(['credit_reporting', 'credit_card', 'credit_reporting',
#        'credit_card', 'mortgage', 'credit_reporting', 'credit_reporting',
#        'debt_collection', 'credit_reporting', 'credit_reporting'],
#       dtype=object)

# %%
rf.predict_proba(text_bow_test)[0:10]
# Out:
# array([[0.02, 0.04, 0.61, 0.28, 0.02, 0.  , 0.03],
#        [0.09, 0.33, 0.33, 0.15, 0.05, 0.  , 0.05],
#        [0.  , 0.02, 0.89, 0.04, 0.04, 0.  , 0.01],
#        [0.06, 0.43, 0.16, 0.22, 0.06, 0.02, 0.05],
#        [0.04, 0.05, 0.09, 0.12, 0.15, 0.02, 0.53],
#        [0.01, 0.  , 0.94, 0.02, 0.01, 0.01, 0.01],
#        [0.12, 0.12, 0.59, 0.1 , 0.03, 0.02, 0.02],
#        [0.02, 0.08, 0.32, 0.51, 0.05, 0.01, 0.01],
#        [0.06, 0.08, 0.56, 0.16, 0.06, 0.04, 0.04],
#        [0.08, 0.08, 0.62, 0.09, 0.01, 0.01, 0.11]])

# %% [markdown]
# ### Random Forest Summary

# %% [markdown]
# The random forest model is probably over-fitting the data and will produce numerous false positives. The cross-validation score is much lower than the model score.
# - Train: 99.91.
# - Test: 82.45

# %% [markdown]
# # Model Comparisons

# %%
bayes_preds[0:20], tree_preds[0:20], forest_preds[0:20]
# Out:
# (array(['credit_reporting', 'credit_card', 'credit_reporting',
#         'credit_card', 'mortgage', 'credit_reporting', 'bank_service',
#         'debt_collection', 'credit_reporting', 'credit_reporting',
#         'bank_service', 'debt_collection', 'credit_reporting', 'loan',
#         'credit_card', 'loan', 'credit_reporting', 'mortgage', 'mortgage',
#         'loan'], dtype='<U16'),
#  array(['credit_reporting', 'credit_card', 'credit_reporting',
#         'credit_card', 'mortgage', 'credit_reporting', 'bank_service',
#         'debt_collection', 'credit_reporting', 'credit_reporting',
#         'bank_service', 'debt_collection', 'credit_reporting', 'loan',
#         'credit_card', 'loan', 'credit_reporting', 'mortgage', 'mortgage',
#         'loan'], dtype='<U16'),
#  array(['credit_reporting', 'credit_card', 'credit_reporting',
#         'credit_card', 'mortgage', 'credit_reporting', 'credit_reporting',
#         'debt_collection', 'credit_reporting', 'credit_reporting',
#         'bank_service', 'debt_collection', 'credit_reporting', 'loan',
#         'credit_card', 'loan', 'credit_reporting', 'mortgage', 'mortgage',
#         'loan'], dtype=object))

# %%
bayes_score, bayes_val_score, tree_score, tree_val_score, forest_score, forest_val_score
# Out:
# (0.8131132473855479,
#  0.8131132473855479,
#  0.9991802667859006,
#  0.8131132473855479,
#  0.9991802667859006,
#  0.8239188215714037)

# %% [markdown]
# # Conclusion
#
# - The Classification and Random Forest models will have a tendency to over-predict.
# - While the Naive Bayes was trained having a lower performnce score (82,44),it will have more accurate predictions.
# - If we had an out-of-time sample, we could perform better validations on the three models.
# - In the mean time, we recommend the Naive Bayes Classification MOdel.

# %% [markdown]
# ## Backup Material

# %% [markdown]
# #### Legend
# - 0 = bank service
# - 1 = credit card
# - 2 = credit reporting
# - 3 = debt collection
# - 4 = loan
# - 5 = money transfers
# - 6 = mortgage

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
comp=bow_transformer.transform(["This company refuses to provide me verification and validation of debt per my right under the FDCPA. I do not believe this debt is mine."])
print(model.predict(comp))
# Out:
# ['debt_collection']

# %%
comp2=bow_transformer.transform(["someone stole my credit card and used it at walmart. I received a credit card alert on my mastercard."])
print(model.predict(comp2))
# Out:
# ['credit_card']

# %%
comp3=bow_transformer.transform(["I am trying tos get a second morgage. the rate on my original mortgage is high."])
print(model.predict(comp3))
# Out:
# ['mortgage']

# %%
comp3=bow_transformer.transform(["I wanted to get a loan to purchase a new car, but they said my credit score was too low due to other outstanding loans. I don't see what the big deal is with having other loans."])
print(model.predict(comp3))
# Out:
# ['loan']

# %% [markdown]
# ## Multi-layer Perceptron Classifier

# %%
from sklearn.neural_network import MLPClassifier
mlpc = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(10, 4), random_state=1)
mlpc.fit(text_bow_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10, 4), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %% [markdown]
# ### MLPClassifier Scores
# #### *Training Accuracy*

# %%
MLPC_score = mlpc.score(text_bow_train, y_train)
MLPC_score
# Out:
# 0.9191711113240288

# %% [markdown]
# #### Validation Accuracy

# %%
MLPC_val_score = mlpc.score(text_bow_test, y_test)
MLPC_val_score
# Out:
# 0.8239064013711901

# %% [markdown]
# The cross-validation score is very close to the model score, 88.21 versus 81.87. The naive Bayes model is a good fit of the data and will produce good predictions.

# %% [markdown]
# ## Multi-class Support Vector Machine

# %%
from sklearn import svm
svm_class = svm.LinearSVC()
svm_class.fit(text_bow_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %% [markdown]
# ### SVM Scores
# #### *Training Accuracy*

# %%
SVM_score = svm_class.score(text_bow_train, y_train)
SVM_score
# Out:
# 0.9570651421758062

# %% [markdown]
# #### *Validation Accuracy*

# %%
SVM_val_score = svm_class.score(text_bow_test, y_test)
SVM_val_score
# Out:
# 0.8096852721265867

# %% [markdown]
# The cross-validation score is very close to the model score, 94.32 versus 81.25. The naive Bayes model is a good fit of the data and will produce good predictions.

# %% [markdown]
# # PART II. Multi-Class Text Classification
#
# ## 7. Data Exploration and Preparation
#
# As we stated in paragraph 3, we perform Multi-Class Text Classification
# using a number of models, including a support vector machine (SVM),
# multinomial Bayes classification mode, random forest classification
# model, and a multinomial logistic regression model. Our goal here is to
# get a better outcome than afforded by our initial analysis (Part I).
#
# ### 7.1. Data Exploration
#
# Before diving into training our machine learning models, we take another
# look at the distribution of complaints in each class using a histogram.

# %%
dfm = df[['product_group','complaint_id','text']]
dfm.head(10)
# Out:
#   product_group  complaint_id  \
# 0  bank_service       2815595
# 1  bank_service       2217937
# 2  bank_service       2657456
# 3  bank_service       1414106
# 4  bank_service       1999158
# 5  bank_service       2862448
# 6  bank_service       1695009
# 7  bank_service       2583952
# 8  bank_service       1988205
# 9  bank_service       2411910
#
#                                                 text
# 0  On check was debited from checking account and...
# 1   opened a Bank of the the West account The acc...
# 2   in nj opened a business account without autho...
# 3  A hold was placed on saving account because in...
# 4  Dear CFPBneed to send a major concerncomplaint...
# 5  Bank closed checking account with no prior war...
# 6   complaint is against Bank have had a account ...
# 7   opened an account on Saturday with  and after...
# 8   business partner and have experienced a total...
# 9   wanted to see can can get a credit increase o...

# %%
df = dfm[pd.notnull(df['product_group'])]
df.columns = ['product_group','complaint_id', 'text']
df['complaint_id'] = df['product_group'].factorize()[0]
category_id_df = df[['product_group', 'complaint_id']].drop_duplicates().sort_values('complaint_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['complaint_id', 'product_group']].values)
df.head()
# Out:
#   product_group  complaint_id  \
# 0  bank_service             0
# 1  bank_service             0
# 2  bank_service             0
# 3  bank_service             0
# 4  bank_service             0
#
#                                                 text
# 0  On check was debited from checking account and...
# 1   opened a Bank of the the West account The acc...
# 2   in nj opened a business account without autho...
# 3  A hold was placed on saving account because in...
# 4  Dear CFPBneed to send a major concerncomplaint...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
plt.bar(10,bank_service_len,3, label="bank_service")
plt.bar(20,credit_card_len,3, label="credit_card")
plt.bar(30,credit_reporting_len,3, label="credit_reporting")
plt.bar(40,debt_collection_len,3, label="debt_collection")
plt.bar(50,loan_len,3, label="loan")
plt.bar(60,money_transfers_len,3, label="money_transfers")
plt.bar(70,mortgage_len,3, label="mortgage")
df.groupby('complaint_id').text.count().plot.bar(ylim=0)
plt.legend()
plt.show()

# %% [markdown]
# ### 7.2. Data Preparation
#
# As before, we first prepare the text for analysis by Vectorizing it,
# although we do it here differently in order to use the text in our
# various models more effectively.

# %%
filtered_text = ["".join(item) for item in X.astype(str)]

# %%
    from nltk.corpus import stopwords 
    from nltk.tokenize import word_tokenize 
    X1 = X.astype(str)
    stop_words = set(stopwords.words('english')) 
    filtered_sentence = [w for w in X1 if not w in stop_words] 
    filtered_sentence = [] 
    for w in X1: 
       if w not in stop_words: 
          filtered_sentence.append(w) 
    filtered_sentence
# Out:
# ["On check was debited from checking account and this check cashed by requested a copy of the endorsement of whom the fund was credited to Bank can't give me satisfactory answer since this contractor breach of contract that needed proof of payment in court ",
#  ' opened a Bank of the the West account The account came with a promotion The promotion was get $100 for setting up a qualifying direct deposit have received that promotion The other promotion was get $50 for making debit card purchases each month for 2 months have met the terms for the $50 promotion and have not received the promotion that am entitled to want the $50 that am entitled to that Bank of the West has not given me ',
#  ' in nj opened a business account without authorization in early and also lied about fees not being charged on a  account have heard nothing about this please let me know how gt part of class action suit NO ONE has contacted me',
#  'A hold was placed on saving account because institution said was making more than transfers a month was stranded in NC with no idea what was going on When was finally able to get speak to someone was informed am being penalized or punished because have made to many transfers First never knew it was wrong to use money work hard for Second because the bank put a hold on account and closed off savings as overdraft account they caused checking to have NSF Then they charged me NSF fees for something they did How do you penalize and steal from hard working people who need their money can see if the money was in accounts but to do intentional damage to your client and then penalize them for your actions in wrong pay bills online because work long hours and to be told you ca get any money via the ATM and you ca use your ATM card is wrong work hours that exceed normal bank hours and it wrong to penalize hard working law abiding citizens and then justify stealing their money because of a hold you placed on them have money in account and want money back for those NSF fees ',
#  'Dear CFPBneed to send a major concerncomplaint about the false advertisement made by Bank to encourage custimers to sign into their Gold account to receive bonus American Airline bonus miles \r\n opened a Gold checking account with more than $ deposited in ec and made several checking activities to meet the bonus miles requirement \r\nBased on the email received attached from in met all of the spending requirements and should receive the bonus miles by 16 \r\nHowever nothing happen and asked to investigate and stil nothing happen for the past 7 weeks when they said they will open an investigation \r\nThere is something wrong for Bank to create this false advertisement to ivite customers to sign up their checking account - without honoring their promise for offering AA bonus miles \r\n am requesting to process their promised bonus miles in the next 30 days \r\nThanks to help many citizens like me having problems with false campaign \r\n\r\n Gold - - - - - - - - - - - - - - - - - - - - - - - From Date Subject Re Promotional Offer Reference Dear Welcome to  Online Message Service name is hope you are having a great day and it is goal to thoroughly address all of your concerns today with your promotion inquiry \r\n\r\n certainly understand your concerns with the status of the investigation on the promotion offer After further review of your account can confirm that the case is still being investigated Once the investigation is completed you will be notified via secure email and Online message with the outcome Please be advised due to the high volume of cases it can take sometime for the case to be resolved As soon as the case is resolved you will be notified via secure email and Online message do apologize for any inconvenience it may poses due to the time it takes to work the case \r\n\r\nPlease note all promotions will differ and are targeted to specific account holders during specific time frames so if you did not receive this promotion via your credit card statement personal email or through U S mail to your home address you will not qualify for this promotion If you have had a previous account with you will not be eligible for the promotion offer We regret if this causes you any inconvenience \r\n\r\n\r\n-- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - From Wise Date Account Number Interest Checking Subject Re Promotional Offer Reference Dear Welcome to Citigold Online Message Service name is and hope that you are having a pleasant day today will be pleased to provide more information regarding your promotion \r\n\r\n can confirm that you completed the requirements for the promotion to receive miles as of 16 Per the promotion policy the AAdvantage bonus miles will be credited by to your AAdvantage account within 90 days from the end of the statement period in which you complete all offer requirements The end of the statement period is 16 \r\n\r\nWith this in mind you should expect to have your miles processed no later than 16 Please note it does take AAdvantage an extra statement cycle to reect the miles online ',
#  'Bank closed checking account with no prior warning on Sunday \r\n\r\nPrior to this on had opened a claim with Bof A as noticed that a merchant had made bitcoin purchases with charged debit card a total of $160 in which never received the bitcoin noticed the issue immediately and reported it to Bof A on same day the transactions posted \r\n\r\n never got a temporary credit for this dispute which thought was very odd so asked Bof A why was told that would get credit no later than 10-days after filing the claim \r\n\r\nLast year had a dispute with but all ended in favor so not sure why that would be a strike against me \r\n\r\n was sick to stomach when tried to use debit card on Sunday and it was rejected went right to check mobile app and it would not allow me to log-in to view account No email no call no letter regarding the closure have done nothing wrong at Bof A to deserve being treated like a criminal can not withdraw any money from checking account at a branch Bof A did tell me they will accept any deposits credits etc that come in but they will reject any auto-payments attempted \r\n\r\nThe closure department said that there is no reason provided for this happening but that they would not report account closure to \r\n\r\n was not a bad customer at Bof A rarely overdrew account and always made weekly deposits If buying bitcoin with debit was an issue they should have made that clear to me and would have stopped immediately \r\n\r\nBof A said the claim will remain open until investigation is complete but presume the bank is just going to reject giving me the money am owed feel like Bof A could and should treat customers better by giving a heads-up when closing any account to allow that person to make other arraignments \r\n\r\nIt is disgraceful and inhumane to allow banks to conduct such horrid behavior towards their customers ',
#  ' complaint is against Bank have had a account with them since we started in with a local bank  bought them and Bank bought Nations started to use debit card & found the account was frozen called for the reason & after being on hold and or different people they said reason was they needed more information and gave me a number to call Monday waited about hrs and called the same number again & told them wanted to talk to their supervisor after more people finally got him He said the reason it was frozen was they had sent out a letter with about questions on it & it had not been returned told him had never gotten it He said anything that important should have been sent Registered Mail ask what the letter was about he said about maybe questions ask what they were & he said the following What Country was you born in was you a US Citizen & where were you living now also the main source of your income the way the country was now they needed this up-dated said you mean they froze account for this They could check this as most all of our checks are direct deposit Our total income is $ less taxes Income derived from pensions farm land rent Bank dividened shares which we inherited Our balance in bank now is $1700 and need to pay monthly bills He gave me a number to call Monday & would Fax information & maybe it could be released by Wednesday would think this would be illegal & certainly not fair am & husband is and certainly not a They had to word it as up date information to keep them legal Then last week checked account & had wrote a check for $240 ch to for Mothers care the next entry was ch for $4200 to and it came bac Insufficient funds but they put that back in there & said was a computer glitch then they charged me $35 for in sufficient funds called again told them off since this was not fault so they took this off think they are out for everything they can get They were so crocked & so greedy they got themselves in this position and the rest of us are paying for this Our Bank stock income was around $ per year & now cent per share We are now in the process of selling bank stock for something to make us more money and changing banks they wo miss us we are to small but if enough did they would realize it When proxy fight was for to keep both positions they called us to see if we would vote for that which we did but it looks like they just try to keep themselves under the legal radar Totally fed up with them & disappointed please help me need our money it is ours & to keep them from doing this to anyone else ',
#  ' opened an account on Saturday with  and after going in to the company to give them opening deposit and requesting an instant issue debit card was told that had to pay them for a charged off account that had with parents when was younger specifically below the age of majority in state After paid the fee called to speak with their complaints department as was blindsided with this information and was then told that could not get a debit card until paid them This entire experience has been horrific and the person spoke to in the complaints department was beyond apathetic and sounded very unknowledgeable regarding the situation after having account pulled up case number is ',
#  ' business partner and have experienced a total breakdown in communication with the  branch The staff have not resolved simple banking issues and do not reply to our calls or emails As a result our company Can not make on-line wire transactions despite compiling all the relevant paperwork in the branch in person in Have not been able to have new cards correctly issued Can not access the account all on line error message account locked ',
#  ' wanted to see can can get a credit increase on credit card from chase bank so asked and at first really did not understand the girl but started to listen really hard and started to pick up what she was talking about we went through the process and then was declined and then she told me that after 180 days you can ask for a increase than told her then why didnt you tell me before because would of said no have only had card for 4 months and at after 3 months you can ask for a credit increase but they didnt tell me until me until after the fact and they keep saying that gave the approval for the go a head to run the credit these people lie just to run your credit score and are very unprofessional while talking to had asked him to let me speak and he did and when asked him a question he would not answer back or respond he would just stay silent then he would say why am letting you talk he was acting like a child ',
#  'Dear Sir or Madam son is a in University He went to the University from our home in by taking ight from to and got to the University on shown in attached proofs pdf \r\n\r\nOn Friday afternoon he got a message from Bank BOA asking him to verify three suspicious transactions from his checking account He messaged me that those transactions were not his and actually happened in and in Texas immediately logged on our account with Bank and found that there were actually four suspicious transactions were being processing at that time Shown in attached proofs pdf 1 Purchase amount $49 approved 2 Purchase amount $47 approved 3 Purchase Amount $43 declined 4 Checkcard Amount $3 Because son is the main user of this shared checking account with me and only he has the debit card with his photo linked to it and knows the PIN number messaged him back that the account is actually his checking account linked with his debit card Since he has his card with him didnt lose the card realized somebody mustve stolen his card information \r\n\r\nSince he was at a meeting at that time while he was replying BOA message to deny the transactions immediately called BOA While was waiting in line with nobody answering phone for about 30-40 mins also transferred the money out of sons account to our saving account in case the bad person continues to make more purchases \r\n\r\nThe line finally picked by a lady after listening to what had happened she assured me that she would freeze the account and file the claim for us that those transactions was not from us She also said son would get another debit card soon By the way son also called BOA later to deny the transactions and he was assured by a gentleman that there was nothing to worry about it They will send him a form to fill it out and he would get another debit card soon son later told me he filled the form online \r\n\r\nWhat surprised me is that on got a letter from BOA that they reviewed the claim number amount $ + $ $97 Transaction 1 and 2 and no posting error has occurred Moreover on got another letter from BOA Claim number amount $140 that they were unable to locate the transaction 3 $43 and therefore all the temporary credits will be reversed \r\n called BOA on that spoke to Gentlemen said that transaction 3 $43 was declined by BOA even before son was contacted so that transaction didnt get through And we didnt claim that amount just told the lady that transactions 1-4 were not ours dont know why we were temporary credit for that amount of $43 But asked why our claim for transactions 1 and 2 were denied as son wasnt in at day the transactions were made He said he would add the new information provided and they would review the case again \r\n\r\nThen on we got another letter from BOA that no posting error has occurred and the claim amount $97 was denied call the number again asked the reason was told by another gentlemen that it was denied because the card and PIN was used for the two transactions asked him how come someone could get sons card and PIN as he has his card with him and never shared his PIN with anybody He told me as long as son uses the card for online purchase the information can be stolen asked him did that mean its not safe to use bank debit card He didnt answer the question just told me that the card and PIN was used in the two transactions then asked him how couldve the transaction 3 been denied if the bad person really had sons PIN before BOA contacted us? then said it looks to me that the bad person didnt have sons PIN thats why he or she was denied for the transaction 3 as many dont bother to ask for PIN even the customers use a debit card He told me the other reason the claim was denied is because there was no other purchases from the debit card from to 16 and they didnt know if son was in Texas during the period said son got his new card more than one week later and even after he got it asked him trying his best not to use it instead use the credit card as the BOA debit ca ...
#  ' discovered that  opened a checking account without authorization in in conjunction with obtaining a mortgage through  only learned about the account when mortgage was paid off and received a statement stating that owed $30 called Wells and was told that the checking account fee had been waived for the 9 6 years had mortgage but that the $30 fee was being assessed since mortgage was paid off never knew had a checking account with  finally convinced a Supervisor to close the account am reporting this since never knew until now that was one of the unauthorized account holders ',
#  'On applied for a personal loan at bank Bank here in the load was for a that was for sale at a very good price So needed to move on the sale was the and man who handled the loan! On called me to come over the bank to sign for the loan when got there he told me for some reason the bank had made it a secured loan with house which was paid for as security home is valued at about did like the idea but thinking was a friend and had been doing business for years with him accepted it mostly because he told me could pay ahead and have it paid off in a short time the loan was for 15 thousand dollars and it was for 25 years have been paying and doubleing up payments and sometimes more noticed that the balance did seem to be going down even though agreement with was that any payment over the base amount would go toward principal! \r\nUpon checking found that the bank had not been doing as they agreed and between till now have paid $9600 in intrest and if continue to pay as they want would be paying over 100 % intrest on this loan would thing that this loan was called a simple intrest loan is named that because a person has to be simple to accept in fact when complaind to the bank the woman laughed and said they do give these loans anymore! woulf like for Bank to go back and figure what ouw then if they would have followed the original agreement had with the loan maker Bank Manager and loan maker!',
#  'In set up a direct deposit account with Bank through work In work called to say the cheques were not going through anymore and told them was out of the country for a month but would look into it when got back In when got back to the US discovered that two of paycheques had not been deposited into account Upon further investigation found out that they had been deposited into an account with a number that was almost the same as account number two numbers had been switched around After hours and weeks of dealing with the bank they told me they were not responsible They told me that ACH handled all direct deposits and that they did not have to check that the name on the account matched the name on the cheques being deposited They said they could do anything was out $720 and was so upset went to the manager at local branch and asked her to help me From her found out that the money went into the account of a woman in area and that she had closed the account after realizing the money was hers With her help we contacted the woman manager and asked her to pay me back the money or would file a complaint with the police After six weeks she finally gave me $200 towards the $720 she owed me That was on In followed up with bank manager and then learned that the woman whose name is did know where the money was coming from did want the money and was told by her bank to close the account The claims person with whom spoke said they could find out where the money was coming from claims find spurious since name and address is on each paycheque and have been a customer at Bank for 10 years In any event instead of trying to contact me at all her bank closed the account and let her keep all of money without ever trying to find me despite what was told earlier this is the bank fault as they could very easily have sorted this matter out by looking at the direct deposits as all information was there have repeatedly asked Bank to compensate me but they are unwilling Originally they deposited the money into account in two installments while they were looking into claim but then took out not two but three installments from account When approached bank manager about this and asked them to give money back they took an extra $340 out so now was out $1000 instead of the original $720 was told by manager that there was no guarantee but they should realize their mistake and should get money back It took three weeks of me complaining but finally got the $340 back from them despite the fact that there were only 12 transactions on the account and they could very easily see their mistake find this whole thing to be ridiculous and BofA to be at fault They should never have given that woman money in the first place they should have checked that the name on the cheque matched the account and they should have looked for me and should have easily found me when the woman told them the money was not hers She should never have been allowed to close this bank account and run with money am still owed $520 and want BofA to pay me immediately work part-time and those two paycheques were a month worth of wages Thank you ',
#  'TD Bank made a deposit in the amount of on account balance prior to the deposit was $1300 According to previous conversations with customer service reps deposits are credited to the account before debits are made On checks were debited from the account in the amount of $1800 and $500 had a bill payment in the amount of $360 and various debit charges totaling $180 According to account view at the time of the withdrawals from account the account balance was $3100 However was still charged $170 in overdraft fees Upon calling to complain was told that only $100 from deposit was actually made available on therefore the funds were not actually available in the account to cover the amounts in the checks posted on thus overdrawing account for the $57 spent over the weekend on debit card $170 for $57 spent when the deposit for $1800 was made into the account If you look at bank account there is no negative balance because the full deposit shows despite the claim that the full amount was not actually credited to account am sick of the criminal nature of the reordering of funds and the blatant disregard of the customers of TD Bank ',
#  'Initiated a Bank money transfer for $600 on This transaction has been done for the past several months in the same fashion Unfortunately this time no email communication was sent to the recipient as has been the case previously Additionally after now three business days the communication nor the funds have been delivered After calling last Friday was told to wait until three business days had passed Called again today and after completing four cold transfers and over one and a half hours on hold finally reached a representative of their Move Money Department that told me the problem was with the receiving bank and that given these known issues it may take up to five business days Having failed to provide notification to the recipient as has happened in the past it seems unlikely the issue is with instead of BofA They did initiate the transfer and took the money from account will have to resend this money while wait up to ten days for them to begin their review of claim requesting money be refunded plus it can take an additional 45 days for them to return the money they have taken from me and failed to deliver to the intended recipient In addition for potentially holding money hostage for 60 days they have advised me that there is no entitlement to compensation They say agreed to some terms but those terms could not be relayed to me on the call nor are they available for review and verification expect this money should be returned with interest comparable to savings account the source from which the money will have to be taken while await their review have an outstanding claim for which can use CFPBassistance in expediting Claim dept phone ',
#  "From had a personal checking account with TCF National Bank During this time suffered the loss of $19000 in overdraft fees due to the following profiteering Bank practices Reordering of Transactions Instead of posting items based on date received TCF Bank manipulated the sequence of customers ' transactions to generate more overdraft income The Bank was very sophisticated in squeezing as much as possible from customers like me frequently pushing what had once been a single overdraft fee of $35 to or overdraft fees $100 or $170 or even more This practice has been widely condemned and many Banks have been fined for it TCF Bank is acknowledged as of the worst offenders \r\n\r\nNSF Placement The Bank essentially charged fees for fees deducting any overdraft fee BEFORE other charges enabling them to charge multiple fees When the Bank changed overdraft fee calculation fees doubledtripled Most heinous of all this process was virtually impossible to stop because you could not tell when and how the Bank was going to manipulate the process and charge more fees As a Judge in another Bank case said Under this system a bone-crushing multiplication of additional overdraft penalties is categorically assured Applying Deposits Last Over time TCF Bank became more and more adept at making sure that deposits were processed after debits In one very obvious instance deposited cash into account which should have been immediately applied to balance then went to a store and made a purchase which went through But later the Bank charged me an overdraft fee claiming that had made the purchase before the deposit In this case had the time stamps from both transactions but the Bank unbelievably refused to consider a refund This was just example of how TCF Bank gamed the system to steal money \r\n\r\nMisinformation regularly used the online account information to check on the status of account But soon realized it was designed to mislead and misinform the customer For instance it always indicated that your balance included all pending transactions But when was charged an overdraft fee for an item was told it was pending but not included in the calculation of the balance Supervisors were never immediately available and almost never called back The more questioned the more the Bank refused to give answers or consider refunds In letter to me the Bank actually stated that if did not like their policies should just leave realized that the pattern of deception was deliberate and anyone who asked too many questions was definitely NOT welcome \r\n\r\nTransfers For a number of years with TCF was either able to complete a transfer or it was declined was never charged an overdraft fee Then noticed that the Bank would approve transfers and balance would show adequate funds online and then after the fact would be charged an overdraft fee Upon inquiry would always be told that had taken the transfer out AFTER a charge had been processed in account but online account had shown adequate funds including pending transactions and regardless the Bank had approved the transfer could not have been aware of a negative situation but the Bank surely would have been and could have declined transfer Instead they approved it and charged me an overdraft fee \r\n\r\nThe predatory practices of this Bank deprived me for years of a huge part of income believe at least 75 % of the charges were deceptive and cost me enormous stress and lost time trying to find remedies live with the understanding that should have changed banks years earlier but still everyone has a right to be protected from this outright theft am therefore seeking the assistance of CFPBin recovering these fees ",
#  'In two 2 unauthorised transactions for appeared on  Monthly Statements disputed them at the County FDIC Cert was given a provisional credit on for only $39 not the $6 transaction and a letter sent stating a provisional credit had been made No mention on of the $ 6 + unauthrorised swipe to pay app transaction - which phone is capable of doing - was ever made The provisional credit was shown on the as provisional credit Meanwhile continued to accrue interest and add applicaple payments see attached for all three documents By  statment there was no mention of anything being made permanent  was in a heap of trouble globablly and was locked out of online account and branch said they could do nothing stopped direct deposit and left enough in the account to avoid banking fees see attached deposited $4500 and spoke with Services Manager who unlocked online account short term and noticed numerous errors in physical address phone and account numbersbut that is another issue escalated the $39 provisional credit and inquired as to why the $6 never had been file as fraud Another escalated ticket was issued see attached The account as of was $1000 see attached Nothing has been done by  No supporting documents substantiating why they refututed the swipe to pay app as unautorized no finalised credit for the $39 and $6 made at the same time has submitted it to and it is on credit report as adverse credit reection See attached ',
#  ' opened an account with  a little over two months ago at the local Branch with a representative named He opened account and set me up with online banking The online banking was to give me an indicator when account fell below $50 The bank started taking fees that made it difficult to keep an accurate accounting had yet to receive an ATM card nor did have access to checking the balance via the phone Technical support could not figure out why the online banking did not send an indicator to cell or email address went into the bank spoke with as fees continued to accrue He shared that it needed to be used with Chrome not Internet Browser Regardless not true but he set it up again The bank refused to refund money which was close to $200 explained that was on SS and the excessive fees were making it impossible to survive that month They said they could not reverse called the corporate office They reversed after stated that was going to contact the received an apology from a representative named Albeit they refused to reverse the fee and the fees for the fees filed a complaint with the then received a phone call from who refunded all During that period of time made a deposit via the ATM It was for $30 but deposited $50 notified of the error deducted from balance and reconciled account including the $50 error We agreed that we would restart account tabula rasa specifically asked if there were any incoming transactions be it from the bank or otherwise that were pending as to circumvent any possibility of the above happening again She stated definitively not The next morning there was a bank charged deducted from account in the amount of $50 It overdrew account This charge would have been noted as pending when spoke with late in the afternoon account overdrew accruing fees up to apx $250 this time reopened claim with the They directed me to contact you from CBleft me a message Monday called her back twice spoke with her Thursday when she returned calls She said that the bank was not in error and had a misunderstanding works for the bank and entity that does not need monthly income on the other hand am struggling to survive on the full income We are not even into a full week out of the month direct deposit has quickly evaporated was in when received call had spent the night there prior Her refusal to reverse the charges upon charges that have amounted to over $250 sent me into needed to spend an extra night which absorbed all of the money remaining positive for the month stated that this was unacceptable shared that found the actions of the bank to be of a retaliatory nature being that the afternoon prior clearly stated that there was not an activity that was going to occur in regard to checking account had spoken with the branch in regard to the $50 the day the online indicator emailed me He did not know what the bank terminology for the debit meant Kindly enough he stated that he would look into it He went home spoke with his manager He stated that needed to balance checkbook have a It is not cognitive This has left me unable to sustain myself and service animal for a week let alone the entire month ',
#  'After a real estate sale deposited the proceeds check from with the local  branch The teller receipt stated the funds would be available the next day The next day requested a payoff for an unrelated mortgage the deposited funds were required for the payoff was alerted through email on that the funds deposited with  would be held for 10 days due to insufficient funds on the Account contacted and was told the funds were in fact available in the account A manager from has provided me a letter stating the date the check cleared attempted to get  to try again to remove the hold but was told it could not be done After the 10 days on proceeded with wiring the funds to payoff mortgage but because of the 10 day delay was required to pay over $400 in additional interest requested from  the additional interest be credited to account since  erroneously held money On was contacted by at the branch that  is prepared to return half of the interest had to pay due to  holding funds without access for 10 days This is not acceptable to me Imagine multiplying amount in question of $280000 by the multitudes of  customers on a yearly basis This illegal process of Gaming as stated recently in a court manipulates money and probably thousands of other  customers to generate interest for  find this gaming practice unethical and possibly criminal This complaint constitutes a formal request to investigate  on this practice of holding customers money after they have received funds in order to generate more income for themselves at the expense of their customers ',
#  ' son who is military has had an account with USAA for 8 years and has never had any kind of issues with his banking or payments In fact he was an exemplary preferred customer in excellent standing He also had his vehicles insured with USAA He even bought his house thru USAA \r\nRecently there seemed to be some unusual activities in and out of his checking account over a span of a few days but nothing was brought to either son or myself his POA with regards to these activities being fraudulent or reason for concern Based on the nature of these occurrences this should have been an obvious RED AG with the bank Instead of putting this thru to their Fraud Dept andor issuing a temporary freeze on the account until an investigation was completed they decided upon themselves to completely and without notice or warning NOT to do business with son any longer and restricted access to retrieving any information about the account altogether \r\n happen to be a person as well as a and have been pursuing this matter on own trying to find some kind of logical explanation These were clearly fraudulent transactions and was not treated as such \r\nUSAA is not a real financial Institution as a normal bank would entail but they are an Investment Corp They do NOT have branches or locations for walk in service except for the one here in TN which is close to went there personally on 16 as was told on the phone that they are not able to speak with me since they no longer do business with son which came as a shock to me informed them that had spoken with CFPBas well as OCC about this situation and in doing so managed to get a copy of the checking account statement which made absolutely NO sense to me as nothing was specified with all the charges racked up by USAA There is so much more to explain after this While being put on hold on the videoconferencing for over 10 minutes immediately got a call from someone on cellphone who indicated to me that SHE would be the one handling this matter and gave me her name and direct number to communicate with her Today is and have never received a response from her even after leaving several messages each day have brought this to the attention of CFPBpreviously but have not filed an official complaint since was under the impression that they were in the process of resolving it \r\nThis does not seem to be the case as they have embarked upon a most unacceptable action that is affecting both son & in a very critical way They have confiscated son BAH since he is in college under the Post G Bill and seems to be applying the full amount wired by The VA ED Dept into his account to all these fraudulent and made up charges by USAA can not get answers from anyone as the customer service people are very limited in whatever information they are told to give me \r\n am son dependent and have no other income to live by have been asking about the auto insurance and still can not get answers from USAA have explained that son was not a beneficiary of any of those fraudulent deposits and withdrawals- if any and his personal information may have been compromised as he had no knowledge of these activities The bank even accepted fraudulent checks made out to third parties with USAA checks not once but twice Yet nothing seemed to be of concern to forward these transactions to the Fraud Dept if in fact there is such a dept with USAA \r\nThere should be a law against this kind of mishandling and negligence with the banks and People Federal Funds wired to their accounts as income am going to inform the VA of this as they have NO right to interfere with Federal Military Deposits \r\nPLEASE HELP ME HERE THIS MAKES NO SENSE AT L Thank you \r\nSincerely ',
#  " incurred 2 overdraft fees on as a result of 2 student loans being debited from account 8 days earlier than usual $360 + $640 It put account in the negative and when charged an $8 caBride on the card again not knowing account was in the negative incurred an additional $38 fee that same day A total of 3 fees on the for a total of $110 \r\n\r\n live in and have a Comerica account in Michigan because of a client have in Michigan deposits checks into account once a month There are no  branches in therefore can't get account into the positive unless either transferred money or ew to Michigan to make the deposit Transferring the money would take usually at least 2 business days usually 3 or 4 and as a result would continue to incur overdraft fees account was a $73 so waiving 2 of the 3 overdraft fees would put me in the positive and would stop the process of additional overdraft fees being charged to the account called customer support on the hoping they would work with me in order for account not to keeping incurring overdraft fees and was told there was nothing they could do In addition they suggested only option was to speak with the bank manager where the account was opened and it would be up to their discretion to waive the fees \r\n\r\nThe person on the phone also notified me that had overdraft fees waived in the past before so it very likely that the manager would not waive these fees This left me with no other option than to either continue incurring the fees until was able to transfer money into the account or y to Michigan to make the deposit When called the bank to speak with the manager the manager refused to waive the fees and was not willing to work with me felt absolutely helpless and the manager and customer service continued to reiterate that there is nothing they could do for me \r\n\r\nWhile understand the fees where incurred as a result of transactions allowed did not expect the bank to refuse to work with me on this case In addition knowing that would continue to incur overdraft fees for a least 2 business days which would continue to drive account into the negative was a viscous and unfair decision by the bank representatives ",
#  'pay pal prepaid works with net spend and they put a block on card but money is on card but cant use it need help getting it unblocked pay pal prepaid works with net spend and they put a block on card but money is on card but cant use it need help getting it unblocked they did even tell me had a block on card had to call and see what was balance and that when they told me filed already dont seems like that is helping so want to take further steps to get card unblocked so basically the money is sitting on card but cant use it because they blocked card plus filed a dispute on regarding a transaction that was not made by me $940 they keeping that and only gave me $170 so basically they giving me what they want to give me dont want half of money want it all ',
#  ' have a checking and savings account wit h USAA Federal Savings Bank bank for many years in They recently shifted to added security at login Supposedly they send a security code to an email address and then you enter the code This is as far as can get on a laptop First they send the code to an old email address no longer associated with account do know what is on profile for sure because can not login By the time get into the old email account copy the code and enter the code it has evidently expired because get an invalid code message tried it three times and no luck The same error message appeared So called customer service three times and once spoke to a security rep supervisor entered SS number 4-digit p in number member ID gave bank debit card information and then they wanted more information about made-up past addresses lik e one from twenty-five yea rs ago wrong address when worked for a company miles away from where live now and ove r ten y ears ago the plant no l onger exists! After another half hour or so the public records proved false so at that point told them the public record information was not right Despite protest that the answers were not correct the rep continued anyway What more could they possibly need well they kept on asking finally said enough! want to close the account But they would not let me cause have not been verified SSN Member ID 25 random o ther passwords and personal information from an incorrect public record ? Please help me get money out of this bank and close this horrible account or make them let me in to own account ',
#  " use bill pay on a regular basis to pay rent this month payment hasn't been delivered with over 10 days they debited account for this whole period as a result apartment is charging me additional late fee and gave me an eviction notice is stating that it out of their control and it not their responsibility ",
#  ' called in and open up account with  360 and was told that violated the terms and conditions and have done anything wrong at all and they also told me that someone open a account in name last year around of and did open it up and at the end was told ca have a  360 checking account ever again',
#  'A account had with you company Account No was closed on Based on a malfunction of your machine that resulted in a loss of funds deposited Because the only means that said account funds could be verified were by human count customer would be responsible for any shortcomings is misplaced Nothing has been provided in regard to the existence of any account much less any mens rea towards impropriety See Attached As such this item should be removed from all reporting agencies immediately ',
#  " name is have an account at  have in the past had problems with  over drafting account even when preferences are set for card to decline if the account has insufficient funds took all the money out of checking account save $6 on with plans to close the account later on Due to past terrible experiences have attached an email detailing those experiences to this complaint put it off until recently checked it and found that it was $100 overdrafted This was due to a $6 payment taken out by a company that had changed payment method with but who apparently did change over payment information for this new card even though inputted it as preferred payment method While they refunded the initial overdraft fee due to this payment there was still a $ deficient that they charged on now from to This defishould have existed at all since was made to understand that the account was set up to not except payments that over drafted the account It was also was previously set up with 'over draft protection ' meaning it would take from the associated savings account if the checking account did have enough funds which would have in this case made it where the account did over draft Meaning that even if neither of the two times went in to correct the problem of account over drafting worked this problem still should not have existed in the first place ",
#  'Paypal put a hold on account and stated that account was linked to an account owing them money told them that account does not belong to me and remove the hold they have not They are also holding money hostage ',
#  'Over several years of service  routinely added service fees to the youth accounts of children even though these types of accounts are supposed to be free of charge while the youth account holder is under the age of according to  advertisements and service agreements On several occasions went to the back to have them reverse the charges After a period of time service charges were added to the youth account again and when the charges depleted the account it was closed by the bank When called the service line for restitution they put me on hold for 30 minutes and told me needed to deal with the branch office The branch office then told me needed to call the service line Since the account was removed from online banking profile can not access the information understand now from the news of  banking practices that this was part of a scheme and not an accident on the part of the banking software as they have tried to tell me ',
#  ' opened an account with HSBC bank because of the $350 offer they mailed to me real simple deposit $10000 into a new account and get the bonus \r\n\r\nWell that was four months ago no bonus and the reps for HSBC are saying two things that even though it been FOUR MONTHS since opened the account that is 8 weeks and that the account that opened was eligible for the bonus either \r\n\r\nSo want the account closed and do not feel should have to pay the early closure fee since they did not live up to their end of the deal and this is clearly fraud that they invite people to open an account that they know is eligible for the bonus only to trap their money in HSBC \r\n\r\n want the account closed no fee and nothing more to do with HSBC bank ',
#  '  360 savings account was hacked It took 3 calls to the security people before they answered account was subsequently locked A week later still do not have access to funds Ive called half a dozen times and waited literally hours on hold without reaching a representative Their voicemail box option is full They are holding funds hostage and can not access them Completely unacceptable ',
# ...
#  ' credit report dated included 15 year mortgages with  Bank The information has been shared with  staff in IA who stated on the phone that they are unable to identify these accounts in name We have NEVER had a 15 year mortgage ',
#  'Identity theft Someone opened up online using name social security and fraudulent home address on ID notified me of issue and called to notify on closed account on but has refused to send letter to me detailing fraud Report from Chex systems lists incorrect address in Fraud and incorrect consumer inquiry Chex Systems states that they can not remove the incorrect information unless contacts them and notifies them of fraud activity and instructs them to remove refuses to do so ',
#  'as statements on account show The bank has been charging me processing fee after processing fee Dispersing money constantly from account Week after week have been stressed over the matter And would like something to be done about it Requested that they put a stop on overdraft fees and they still continued to overdraw me felt as if they have stolen money from me Purposely ',
#  'On made an online ACH payment through the Bank website for $500 on credit card According to 2 minutes after $500 payment they claim that requested for account to be enrolled in auto pay of entire balance each month did not authorize this and had no idea that they did this On made an unauthorized ACH withdrawal of $3700 from checking account contacted and told them that this was fraudulent and they not only denied me but they hung up the phone on me They did send me a new credit card as if they thought it was compromised Then called who told me that they had to investigate the complaint At this time was traveling on military duty and Wife and Kids were traveling in orida We were all left without access to our own money because of the issue and it has cost us money ever since Since this has happened have made complaints with the orida Attorney General and the County Sheriff Please help leaning lesson is that ACH withdrawals are not protected the same way that credit card and debit card withdrawals are covered by federal law ',
#  'On at approx went into  to open 2 accounts business and personal It became late and they experienced a glitch in their system and asked if could return the next day agreed The next day came in and they told me that they are not able to open an account for me due to saying owed money to another bank They told me to go to the banks and clear it up and come back to them with letters and they would give me back money They were clear in saying that they would not be opening an account however went to the banks and discovered that after closed bank account auto pay items went through and created an outstanding balance immediately rectified the issue which in total was roughly $350 On took letters into Comerica and asked for them to give me money back as they told me they were not opening an account They then informed me that even though they said they werent going to open an account for me they went ahead and deposited money and now would have to wait 9 days was frustrated and told them would return to pick up funds specifically requested to pick up money because was anticipating moving in the next week went back in on on the and they told me money was still not available again told them would be back to pick up check was sick the week of and they called me 3 times in 2 days went in on to get funds and they told me they had mailed them to me They said they mailed it out on On still had not received check had mail held on due to Comericas mailing check and specifically to make sure the check would be at the post office went in to pick up held mail on the The check was not there called and told him had not received a check in a 10-day period and wanted that one cancelled and a new check reissued He was rude and told me he could not help me until Monday asked for his manager to call me back He told me she was working from home asked that she call me on her cell She did not The bank was also open on Saturday and still did not hear from anyone On Monday at called the bank and asked for She lied to me and said she was out of town when last week told me that she was working from home on Friday asked her where check was and she gave me the run around and said she was just finding this out do not believe that as told wanted her informed on Friday told her to figure out the timeline for getting me a check that could come to the bank and pick up ensured she had cell phone number and told her to call me back with that info by EOBShe did not call me do not have money still It is now the and the manager has still not contacted me about how to get funds Comerica has kept money for 30 days have had damages due to this inability to access funds This is a ridiculous amount of time for them to hold money while they benefit from it being deposited in their institution ',
#  'On while was doing taxes noticed several large unauthorized transactions on account There were 15 transactions totaling $2300 that DID NOT authorize Let me first start off by saying that did do business with the merchant prior to these charges posting to checking account But these 15 transactions that filed a claimdispute over did not authorize them did not receive any good nor services from them in return This is not a case where paid the merchant and happy with the goodsservices This is not a case where was charged a wrong amount This is a case where at out fraud occurred Money was taken out of account without permission This is fraud When called Bank let them know that the merchant was and filed the claim When filed the claim the rep from BoA stated to me that if this was not resolved within 10 business days that would receive a provisional credit \r\n\r\nWell that 10 days went by and there was no resolution and there was no provisional credit called BoA again and they stated that the rep misinformed me This rep stated that the original rep filed the claim as a merchant dispute rather than fraud They explained to me the difference to me They stated that since did business with the merchant prior that could not file it as fraud even though did not authorize a single one of the 15 charges found this mind boggling to say the least literally stole money out of account and BoA is treating it as a misunderstanding between me and During the phone call the rep stated they were escalating this case to a claims specialist and that hopefully that would progress case a little faster \r\n\r\nAs several days went on called several times to Bank During this entire time also was doing due diligence and was in touch with several times as well A female rep at stated to me that card was used on several accounts that were not mine She also stated that which was on account was attempted by someone on another account 3-4 times but none succeeded faxed newfound information to Bank called several more times to BoA to see if there were any new updates \r\n\r\nWell on called BoA again This time spoke with a rep named She was actually very helpful explained the whole situation over once again and she agreed that this was clear fraud She escalated case and said she put a request for case to change to fraud from merchant dispute She stated that a claims specialist should review case and should have an answer within 10-15 days hung up the phone thinking for once that maybe just maybe things would start to move \r\n\r\nOn woke up early in the morning and logged onto the BoA website and went into the message center where the claim updates would post To surprise it finally changed from being reviewed to resolved claim paid was very excited and called BoA soon as they opened spoke with He stated he did not see anything on his end where it said the case was resolved Later in the day called again and spoke with spelling might be wrong was super super helpful and put me on hold while she researched what was going on She was working with her supervisor and found out that the case was resolved and that it was ruled in favor asked her how come no money posted to account She said it could take up to 90 days from when filed claim which would be dont understand why wouldnt receive money if the claim was ruled in favor \r\n\r\n have been looped in circles time after time by BoA was misinformed from the start about receiving a provisional credit This is a lot of money to me and it caused me great hardship truly believe claim was mishandled from the start and should have been filed as fraud should have received provisional credit and this case would be done by now \r\n\r\nThe case is now resolved and it states that the claim is paid but no money has been returned to me BoA is holding onto money and have been given no legit reason why stated that BoA reversed the charges and that should handle everything with BoA from here on out feel like no one is helping me and fel ...
#  'Consumer Financial Protection Bureau Page of Re Complaint on Actions of PNC Bank Failure to provide Response as Committed This complaint relates to the unprofessional conduct on the part of PNC Bank representatives actions against family unrelated to any pers onal dispute have had failure to provide timely accurate information and for a lack of factual information There was a previous complaint which did not include items covered here Comments on the lette r not sent to me but to the CFPBby are included Additional reference documents are also included with this complaint PNC Bank has not provided common information requested assistance through channels they directed me and family to has posed risks to my wifes and our family accounts including SS and insurance Through failure to properly allow me to make deposits use checking and investment accounts credit risks were posed For many months ending with PNC Banks closure of several accounts and wife had not been able to obtain committed advice or direction from PNC Bank representatives as required in their agreements for these accounts Clo sures were well from 12 to 30 days as there were holidays and weekends involved se e attached below any reasonable number expected for major account funds transfers Even the closure notices are inconsistent The note from dated received on or about gives notice of account closure by This is less than 12 days This first notice was shortly after PNC representatives would not provide assistance This is retaliatory noting else Is this proper or fair treatment? Commitments by designated PNC Bank contact after the CFPBcomplaint have not been completed and summary statements posed By PNC to C FPBand others are absolutely false and defamatory Related to the PNC Branch manager aggre ssive behavior was shown by him on Details are included below and in an attachment The forgery of documents claims are founded counter to statement will make myself available at any time to undergo handwriting analysis to compare known signature to those poste d One oBvious example is attached When the investment advisor involved was originally approached of the forgeries he noted that the signatures must have been done by someone at the corporate level He fully agreed they were not mine Comment was made by me that forgery is a bad habit-no matter who did it When a representat ve of PNC Bank itself has agreed this hardly matches unfounded comment on forgery Direct testimony by should have been enough to convinc e PNC tha t something major was wrong Statements otherwise now by or any others are completely false and do not match the real documents Failure to Assist and Provide Information on Special Loan Offer The letter from states that the accounts were closed because of consistent and repeated instances of aggressive behavior at the Branch This is totally and absolutely false have never had any confrontation with any regula r PNC bankin g representative On or about nearly a year ago had requested directly from the available local branch PNC Investment Representative copies of L signed documents in PNC files for myself and wife The request was made due to an ongoing issue related to forgery of documents by PNC A copy of one forged item is attached The document copies were to include all in PNC files She agreed with no questions with an expectat on within a few days A reference is in the attached note to Some investment documents including forgeries were provided Many others were not This failure showed an unacceptable lack of respect and common banking courtesy Multiple accounts were open at that time with many signature documents available in PNC records Since an issue related to a forgery by PNC had already gone on for an extended time was rightly disappointed A request for a follow up call from the bank manager was not completed This matched a previous pattern from PNC There has been no refusal by me for assistance None has been offered Through the year continued to regu ...
#  ' tried to ask  if they could please help me investigate a scam issue that occurred to account but they refused to help with any issue as  not a customer am a customer with that refuses to help me as well as think it is the bank responsibility to help me recover the lost funds in account and track down the scammers of the bad check should be held accountable for processing the bad check and allowing me to withdrawal the large amount from the processed check and depositing it into a  account as was instructed to Neither banks are trying to help me recover the funds nor catch the scammers The local authorities are able to do much if the bank does cooperate believe it should be the bank responsibility to catch a bad check in a timely manner and help their customers in every way possible to prevent this from happening to other people ',
#  ' am having an issue with  TDBANK_US allowing charges to go through on a debitcharge card on a weekly basis have spent hundreds of dollars monthly on over draft fees am a small business owner with very little income and struggle to balance maintaining clients as well as finances  TDBANK_US allows charges to go through on debit cards when there is not money in the account they end up hitting me with over drafts and it ends up snow balling the problem with more over drafts have spook with local branch manager and he told me that there is no protection for business owners only consumers in the past two years have paid in on over drafts approximately $2500 in over drafts which cant afford think something should be done with this and stop  TDBANK_US from charging cards that have no funds on them',
#  'my bank has extended the time frame to pay mortgage to 5 days it used to be 1-2 days asked them to explain they told me the mortgage bank accepts only checks in fact they told me this twice which is a lie a banker from bank called the mortgage bank and clarified that no changes were made regarding payment with me as third party witness now bank says the mortgage company sets the conditions for payments online this month 900 plus payment was taken out of account on the to reach the mortgage bank on the this is a 9 day hold and yet other bank payments are only a 2 day hold there is something going on that seems off was told to just have mortgage company deduct the amount from account every month this is not acceptable and they wo even admit have been lied to want to know why only this account is affected what do they gain? an extra few days to oat $ to their advantage this seems like a way to scam customers ',
#  ...]

# %%
# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in filtered_sentence]
print(stripped[:100])
# Out:
# ['On check was debited from checking account and this check cashed by requested a copy of the endorsement of whom the fund was credited to Bank cant give me satisfactory answer since this contractor breach of contract that needed proof of payment in court ', ' opened a Bank of the the West account The account came with a promotion The promotion was get 100 for setting up a qualifying direct deposit have received that promotion The other promotion was get 50 for making debit card purchases each month for 2 months have met the terms for the 50 promotion and have not received the promotion that am entitled to want the 50 that am entitled to that Bank of the West has not given me ', ' in nj opened a business account without authorization in early and also lied about fees not being charged on a  account have heard nothing about this please let me know how gt part of class action suit NO ONE has contacted me', 'A hold was placed on saving account because institution said was making more than transfers a month was stranded in NC with no idea what was going on When was finally able to get speak to someone was informed am being penalized or punished because have made to many transfers First never knew it was wrong to use money work hard for Second because the bank put a hold on account and closed off savings as overdraft account they caused checking to have NSF Then they charged me NSF fees for something they did How do you penalize and steal from hard working people who need their money can see if the money was in accounts but to do intentional damage to your client and then penalize them for your actions in wrong pay bills online because work long hours and to be told you ca get any money via the ATM and you ca use your ATM card is wrong work hours that exceed normal bank hours and it wrong to penalize hard working law abiding citizens and then justify stealing their money because of a hold you placed on them have money in account and want money back for those NSF fees ', 'Dear CFPBneed to send a major concerncomplaint about the false advertisement made by Bank to encourage custimers to sign into their Gold account to receive bonus American Airline bonus miles \r\n opened a Gold checking account with more than  deposited in ec and made several checking activities to meet the bonus miles requirement \r\nBased on the email received attached from in met all of the spending requirements and should receive the bonus miles by 16 \r\nHowever nothing happen and asked to investigate and stil nothing happen for the past 7 weeks when they said they will open an investigation \r\nThere is something wrong for Bank to create this false advertisement to ivite customers to sign up their checking account  without honoring their promise for offering AA bonus miles \r\n am requesting to process their promised bonus miles in the next 30 days \r\nThanks to help many citizens like me having problems with false campaign \r\n\r\n Gold                        From Date Subject Re Promotional Offer Reference Dear Welcome to  Online Message Service name is hope you are having a great day and it is goal to thoroughly address all of your concerns today with your promotion inquiry \r\n\r\n certainly understand your concerns with the status of the investigation on the promotion offer After further review of your account can confirm that the case is still being investigated Once the investigation is completed you will be notified via secure email and Online message with the outcome Please be advised due to the high volume of cases it can take sometime for the case to be resolved As soon as the case is resolved you will be notified via secure email and Online message do apologize for any inconvenience it may poses due to the time it takes to work the case \r\n\r\nPlease note all promotions will differ and are targeted to specific account holders during specific time frames so if you did not receive this promotion via your credit card statement personal email or throu ...

# %%
exclude = set(string.punctuation)
clean_text = ''.join(ch for ch in filtered_sentence if ch not in exclude)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
features = tfidf_transformer.fit_transform(X_train_counts)
labels = X_train

# %%
print(features)
# Out:
#   (0, 41431)	0.08285179115718981
#   (0, 26720)	0.2764500309596693
#   (0, 45135)	0.057745381495485304
#   (0, 43488)	0.1775152745142489
#   (0, 10133)	0.17412724597977397
#   (0, 49234)	0.24605177444761792
#   (0, 86703)	0.058852593316320256
#   (0, 85981)	0.1892005811586917
#   (0, 70719)	0.16414838350799613
#   (0, 95212)	0.13243141159552738
#   (0, 42020)	0.05661435057574735
#   (0, 36055)	0.2912141526276478
#   (0, 13048)	0.19455875761141267
#   (0, 61839)	0.0551398046122844
#   (0, 52958)	0.1526857233291632
#   (0, 29497)	0.22370840252343893
#   (0, 48713)	0.0669185538932523
#   (0, 95503)	0.06199517654686664
#   (0, 52847)	0.1038271771835712
#   (0, 21763)	0.16776731209419463
#   (0, 82148)	0.1396143504832041
#   (0, 85898)	0.1110451705031512
#   (0, 95997)	0.08922015211886304
#   (0, 59737)	0.05709955972432531
#   (0, 12693)	0.07646776290410011
#   :	:
#   (187865, 74678)	0.0987259239409822
#   (187865, 90176)	0.07484416198225746
#   (187865, 92362)	0.19641401792554275
#   (187865, 91592)	0.056431870306139796
#   (187865, 29836)	0.07196374967186639
#   (187865, 83583)	0.08422441681801326
#   (187865, 13131)	0.16368666214302036
#   (187865, 72144)	0.10491730897717054
#   (187865, 6265)	0.07683323832003701
#   (187865, 46583)	0.10945274195901371
#   (187865, 63528)	0.0837684352336598
#   (187865, 59896)	0.08052619284813138
#   (187865, 79397)	0.08216733067106889
#   (187865, 63526)	0.23504662154785488
#   (187865, 21152)	0.09176397147591994
#   (187865, 58138)	0.11060826364053991
#   (187865, 93209)	0.0911766412880154
#   (187865, 34566)	0.08826607931648821
#   (187865, 35914)	0.08365309749682108
#   (187865, 24031)	0.10756018768622617
#   (187865, 34658)	0.10617927142887978
#   (187865, 83649)	0.13106547035114233
#   (187865, 72742)	0.14441665087529362
#   (187865, 2080)	0.16493527385637097
#   (187865, 67176)	0.17883082909948653

# %% [markdown]
# ### 7.3. Checking the Data
#
# Here we choose to check our vectorized data using Chi-Square testing and
# examining unigrams and bigrams for each SCRA Issue (class). This will
# give us an idea of the most important words and pair of words in the
# text as they pertain to classification of complaints. Note that ``Well
# Fargo'' is a bigram for ``Excessive Interest'' Perhaps suprisingly,
# ``"Well Fargo'' appears in the transcripts of USAA SCRA calls, probably
# due to the high interest rates they were demanding from service members.
# As a result of these violations, we should take care to note these as we
# discuss SCRA with our members, who may have formally sought loans from
# Wells Fargo, for instance. The other unigrams and bigrams should be
# apparent.

# %% [markdown]
# ## 8. Model Development and Execution
#
# Here we prepare to implement and run our four models.
#
# ### 8.1. Model Preparation
#
# As before, we define training and test sets and prepare them for a BOW
# analysis with our models.

# %%
df = corps
df = df[pd.notnull(df['product_group'])]
df.columns = ['product_group','text']
df['category_id'] = df['product_group'].factorize()[0]
category_id_df = df[['product_group', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'product_group']].values)
df.head()
# Out:
#   product_group                                               text  \
# 0  bank_service  On check was debited from checking account and...
# 1  bank_service   opened a Bank of the the West account The acc...
# 2  bank_service   in nj opened a business account without autho...
# 3  bank_service  A hold was placed on saving account because in...
# 4  bank_service  Dear CFPBneed to send a major concerncomplaint...
#
#    category_id
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
dta = pd.read_csv("D:/Documents/Data/case_study_data_copy.csv")
corps = dta[['product_group','text']]
X = corps.text
y = corps.product_group
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = np.array(tfidf.fit_transform(X_train))
labels = corps.product_group

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for product_group, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(product_group))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f98250b1d168> in <module>
#       3 N = 2
#       4 for product_group, category_id in sorted(category_to_id.items()):
# ----> 5   features_chi2 = chi2(features, category_id)
#       6   indices = np.argsort(features_chi2[0])
#       7   feature_names = np.array(tfidf.get_feature_names())[indices]
#
# ~\Anaconda\lib\site-packages\sklearn\feature_selection\univariate_selection.py in chi2(X, y)
#     211     # XXX: we might want to do some of the following in logspace instead for
#     212     # numerical stability.
# --> 213     X = check_array(X, accept_sparse='csr')
#     214     if np.any((X.data if issparse(X) else X) < 0):
#     215         raise ValueError("Input X must be non-negative.")
#
# ~\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: setting an array element with a sequence.

# %%
from sklearn.feature_selection import chi2
import numpy as np
#vectorizer = TfidfVectorizer()
features = vectorizer.fit_transform(text_bow_train, y_train)#vectorizer.fit_transform(X_train)
N = 2
for product_group, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == product_group)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(vectorizer.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(product_group))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-b027647c2dd1> in <module>()
#       2 import numpy as np
#       3 #vectorizer = TfidfVectorizer()
# ----> 4 features = vectorizer.fit_transform(text_bow_train, y_train)#vectorizer.fit_transform(X_train)
#       5 N = 2
#       6 for product_group, category_id in sorted(category_to_id.items()):
#
# ~\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1379             Tf-idf-weighted document-term matrix.
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#    1383         # X is already a transformed view of raw_documents so
#
# ~\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# ~\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# ~\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# ~\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(x)
#     230
#     231         if self.lowercase:
# --> 232             return lambda x: strip_accents(x.lower())
#     233         else:
#     234             return strip_accents
#
# ~\Anaconda\lib\site-packages\scipy\sparse\base.py in __getattr__(self, attr)
#     684             return self.getnnz()
#     685         else:
# --> 686             raise AttributeError(attr + " not found")
#     687
#     688     def transpose(self, axes=None, copy=False):
#
# AttributeError: lower not found

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)#count_vect = CountVectorizer()
#X_train_counts = count_vect.fit_transform(X_train)
#tfidf_transformer = TfidfTransformer()
#X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(text_bow_train, y_train)

# %% [markdown]
# ### 8.2. Model Execution
#
# Now we setup and run the four models uing our BOWs.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]

# %%
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-e1ccd02ec700> in <module>()
#       4 for model in models:
#       5   model_name = model.__class__.__name__
# ----> 6   accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
#       7   for fold_idx, accuracy in enumerate(accuracies):
#       8     entries.append((model_name, fold_idx, accuracy))
#
# ~\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ~\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     190
#     191     """
# --> 192     X, y, groups = indexable(X, y, groups)
#     193
#     194     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#
# ~\Anaconda\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# ~\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     198     """
#     199
# --> 200     lengths = [_num_samples(X) for X in arrays if X is not None]
#     201     uniques = np.unique(lengths)
#     202     if len(uniques) > 1:
#
# ~\Anaconda\lib\site-packages\sklearn\utils\validation.py in <listcomp>(.0)
#     198     """
#     199
# --> 200     lengths = [_num_samples(X) for X in arrays if X is not None]
#     201     uniques = np.unique(lengths)
#     202     if len(uniques) > 1:
#
# ~\Anaconda\lib\site-packages\sklearn\utils\validation.py in _num_samples(x)
#     117         if len(x.shape) == 0:
#     118             raise TypeError("Singleton array %r cannot be considered"
# --> 119                             " a valid collection." % x)
#     120         return x.shape[0]
#     121     else:
#
# TypeError: Singleton array array(MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True),
#       dtype=object) cannot be considered a valid collection.

# %%
## 9. Model Analysis

Now we turn to our analysis of the models output and performance.

### 9.1. Anlysis of Model Performance

To start with, we can see on the graph above our models from lef to
right: the random forest classification model, the support vector
machine (SVM), the multinomial Bayes classification mode, and the
multinomial logistic regression model. From the graph it appears that
the SVM provides the best performance. This is supported by the model
accuracy metric shown below, with about 98%.

# %%
cv_df.groupby('model_name').accuracy.mean()

# %%
### 9.2. Confusion Matrix

Here, we cut to the chase and look at the confusion matrix provided by
the SVM. Although we show the confusion matrix, the normalized confusion
matrix is more informative (section 9.3).

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.SCRA_ISSUE.values, yticklabels=category_id_df.SCRA_ISSUE.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
=== 9.3. Normalized Confusion Matrix

Given the matrix below and 96.653% accuracy:

* ``Eviction'' is accurately 93.4% of the time, and incorrectly
classifies an SCRA issue as ``None'' 6.6% of the time.
* ``Excessive Interest'' is accurately 86.1% of the time, and
incorrectly classifies an SCRA issue as ``Eviction'' 0.4% of the time,
``Foreclosure'' 9.1% of the time, ``None'' 4.1% of the time, and
``Repossession'' 0.4% of the time.
* ``Foreclosure'' is accurately 84.9% of the time, and incorrectly
classifies an SCRA issue as ``Eviction'' 2.7% of the time, ``Excessive
Interest'' 8.9% of the time, and ``None'' 3.5% of the time.
* ``None'' is accurately 100.0% of the time.
* ``Repossession'' is accurately 50.0% of the time, and incorrectly
classifies an SCRA issue as ``Excessive Interest'' 31.5%" of the time,
and ``None'' 18.5% of the time.

Recall = 82.9%, Precision is 90.1%, and the F1 Score is 85.0%

# %%
result = model.score(X_test, y_test)
print("Accuracy: %.3f%%" % (result*100.0))
y_pred = model.predict(X_test)
print("F1 Score: ", f1_score(y_test, y_pred, average="macro"))
print("Precision Score: ", precision_score(y_test, y_pred, average="macro"))
print("Recall Score: ", recall_score(y_test, y_pred, average="macro")) 
cm_analysis(y_test, y_pred, model.classes_, ymap=None, figsize=(10,10))

# %% [markdown]
# 9.4. Anecdotal Evidence
#
# For anecdotal evidence, we printed out five excerpt from the predicted
# data. All are well within reason, provided the resullts shown by the
# confussion matrix.

# %%
from IPython.display import display
for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 10:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['SCRA_ISSUE', 'COMPLAINT']])
      print('')

# %%
9.5. Unigrams and Bigrams

Notice the similaries and differences between with our earlier analysis.

# %%
model.fit(features, labels)
N = 2
for Product, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(Product))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))

# %%
9.6. Detailed Metrics

The following provides the details that we summarized in section 9.3.

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, target_names=df['SCRA_ISSUE'].unique()))
